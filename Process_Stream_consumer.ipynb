# %%
# import statements
from time import sleep
from kafka import KafkaConsumer
import datetime 
import matplotlib
import matplotlib.pyplot as plt
import time
from json import loads

# %%
# import statements
from time import sleep
from kafka import KafkaConsumer
import datetime
import matplotlib
import matplotlib.pyplot as plt
import dateutil.relativedelta
# this line is needed for the inline display of graphs in Jupyter Notebook
# %matplotlib notebook

topic = 'process'

def connect_kafka_consumer():
    _consumer = None
    try:
         _consumer = KafkaConsumer(topic,
                                   consumer_timeout_ms=10000, # stop iteration if no message after 10 sec
                                   auto_offset_reset='latest', # comment this if you don't want to consume earliest available message
                                   bootstrap_servers=['localhost:9092'],
                                   value_deserializer=lambda x: loads(x.decode('ascii')),
                                   api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _consumer


    
def consume_messages(consumer, fig, ax):
    try:
        # print('Waiting for messages')
        for message in consumer:
            print(message)
    except Exception as ex:
        print(str(ex))
        
    
if __name__ == '__main__':
    
    consumer = connect_kafka_consumer()
    consume_messages(consumer,fig,ax)
# Out:
# ConsumerRecord(topic='process', partition=0, offset=9737, timestamp=1616393914852, timestamp_type=0, key=None, value={'sequence': 1570, 'machine': 4, 'PID': 2420, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '-', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'dbus-daemon', 'ts': 1616393914}, headers=[], checksum=1841277399, serialized_key_size=-1, serialized_value_size=233, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9738, timestamp=1616393914853, timestamp_type=0, key=None, value={'sequence': 1571, 'machine': 4, 'PID': 1371, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '-', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'irqbalance', 'ts': 1616393914}, headers=[], checksum=1544967180, serialized_key_size=-1, serialized_value_size=232, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9739, timestamp=1616393914853, timestamp_type=0, key=None, value={'sequence': 1572, 'machine': 4, 'PID': 2498, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '-', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'upstart-dbus-b', 'ts': 1616393914}, headers=[], checksum=2002427207, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9740, timestamp=1616393914853, timestamp_type=0, key=None, value={'sequence': 1573, 'machine': 4, 'PID': 8486, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': '-', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'kworker/u256:1', 'ts': 1616393914}, headers=[], checksum=3536348651, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9741, timestamp=1616393914853, timestamp_type=0, key=None, value={'sequence': 1574, 'machine': 4, 'PID': 3793, 'TRUN': 1, 'TSLPI': 11, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '-', 'EXC': 0, 'State': 'S', 'CPU': 0.98, 'CMD': 'drone', 'ts': 1616393914}, headers=[], checksum=2028915377, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9742, timestamp=1616393914854, timestamp_type=0, key=None, value={'sequence': 1575, 'machine': 4, 'PID': 6847, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '-', 'EXC': 0, 'State': 'S', 'CPU': 0.02, 'CMD': 'tcpdump', 'ts': 1616393914}, headers=[], checksum=3041064010, serialized_key_size=-1, serialized_value_size=230, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9743, timestamp=1616393914854, timestamp_type=0, key=None, value={'sequence': 1576, 'machine': 4, 'PID': 2774, 'TRUN': 0, 'TSLPI': 9, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': '-', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'compiz', 'ts': 1616393914}, headers=[], checksum=2297458741, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9744, timestamp=1616393914854, timestamp_type=0, key=None, value={'sequence': 1577, 'machine': 4, 'PID': 2533, 'TRUN': 0, 'TSLPI': 4, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '-', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'hud-service', 'ts': 1616393914}, headers=[], checksum=2920394522, serialized_key_size=-1, serialized_value_size=234, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9745, timestamp=1616393914854, timestamp_type=0, key=None, value={'sequence': 1578, 'machine': 4, 'PID': 4373, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 2, 'Status': '-', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'atop', 'ts': 1616393914}, headers=[], checksum=3353928714, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9746, timestamp=1616393914854, timestamp_type=0, key=None, value={'sequence': 1579, 'machine': 4, 'PID': 4375, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 2, 'Status': '-', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'atop', 'ts': 1616393914}, headers=[], checksum=1290041417, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9747, timestamp=1616393914855, timestamp_type=0, key=None, value={'sequence': 1580, 'machine': 4, 'PID': 4374, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 0, 'Status': '-', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'atop', 'ts': 1616393914}, headers=[], checksum=1678079564, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9748, timestamp=1616393914855, timestamp_type=0, key=None, value={'sequence': 1581, 'machine': 4, 'PID': 3676, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 0, 'Status': '-', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'atop', 'ts': 1616393914}, headers=[], checksum=4097137206, serialized_key_size=-1, serialized_value_size=227, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9749, timestamp=1616393914856, timestamp_type=0, key=None, value={'sequence': 1582, 'machine': 4, 'PID': 3677, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 0, 'Status': '-', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'atop', 'ts': 1616393914}, headers=[], checksum=1563978138, serialized_key_size=-1, serialized_value_size=227, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9750, timestamp=1616393914856, timestamp_type=0, key=None, value={'sequence': 1583, 'machine': 4, 'PID': 3678, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 3, 'Status': '-', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'atop', 'ts': 1616393914}, headers=[], checksum=2897568150, serialized_key_size=-1, serialized_value_size=227, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9751, timestamp=1616393914861, timestamp_type=0, key=None, value={'sequence': 1584, 'machine': 4, 'PID': 3675, 'TRUN': 1, 'TSLPI': 0, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 0, 'Status': '-', 'EXC': 0, 'State': 'R', 'CPU': 0.0, 'CMD': 'atop', 'ts': 1616393914}, headers=[], checksum=1809088599, serialized_key_size=-1, serialized_value_size=227, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9752, timestamp=1616393915118, timestamp_type=0, key=None, value={'sequence': 1429, 'machine': 5, 'PID': 2442, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'window-stack-b', 'ts': 1616393915}, headers=[], checksum=1310598417, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9753, timestamp=1616393915119, timestamp_type=0, key=None, value={'sequence': 1430, 'machine': 5, 'PID': 1854, 'TRUN': 0, 'TSLPI': 2, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'vmtoolsd', 'ts': 1616393915}, headers=[], checksum=2729368820, serialized_key_size=-1, serialized_value_size=230, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9754, timestamp=1616393915120, timestamp_type=0, key=None, value={'sequence': 1431, 'machine': 5, 'PID': 1667, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'haveged', 'ts': 1616393915}, headers=[], checksum=1772842254, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9755, timestamp=1616393915121, timestamp_type=0, key=None, value={'sequence': 1432, 'machine': 5, 'PID': 2326, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'init', 'ts': 1616393915}, headers=[], checksum=1570951636, serialized_key_size=-1, serialized_value_size=226, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9756, timestamp=1616393915122, timestamp_type=0, key=None, value={'sequence': 1433, 'machine': 5, 'PID': 1423, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'irqbalance', 'ts': 1616393915}, headers=[], checksum=1876982849, serialized_key_size=-1, serialized_value_size=232, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9757, timestamp=1616393915122, timestamp_type=0, key=None, value={'sequence': 1434, 'machine': 5, 'PID': 2505, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'upstart-dbus-b', 'ts': 1616393915}, headers=[], checksum=2441818105, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9758, timestamp=1616393915122, timestamp_type=0, key=None, value={'sequence': 1435, 'machine': 5, 'PID': 3615, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'kworker/3:2', 'ts': 1616393915}, headers=[], checksum=1258124227, serialized_key_size=-1, serialized_value_size=233, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9759, timestamp=1616393915122, timestamp_type=0, key=None, value={'sequence': 1436, 'machine': 5, 'PID': 4326, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.03, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=754129771, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9760, timestamp=1616393915123, timestamp_type=0, key=None, value={'sequence': 1437, 'machine': 5, 'PID': 2536, 'TRUN': 1, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'R', 'CPU': 0.03, 'CMD': 'hud-service', 'ts': 1616393915}, headers=[], checksum=309563945, serialized_key_size=-1, serialized_value_size=234, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9761, timestamp=1616393915123, timestamp_type=0, key=None, value={'sequence': 1438, 'machine': 5, 'PID': 2777, 'TRUN': 0, 'TSLPI': 5, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'R', 'CPU': 0.03, 'CMD': 'compiz', 'ts': 1616393915}, headers=[], checksum=2922485955, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9762, timestamp=1616393915123, timestamp_type=0, key=None, value={'sequence': 1439, 'machine': 5, 'PID': 4188, 'TRUN': 1, 'TSLPI': 12, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.02, 'CMD': 'drone', 'ts': 1616393915}, headers=[], checksum=4084062381, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9763, timestamp=1616393915123, timestamp_type=0, key=None, value={'sequence': 1440, 'machine': 5, 'PID': 4327, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.02, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=2164090547, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9764, timestamp=1616393915123, timestamp_type=0, key=None, value={'sequence': 1441, 'machine': 5, 'PID': 4185, 'TRUN': 0, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'ostinato', 'ts': 1616393915}, headers=[], checksum=25763224, serialized_key_size=-1, serialized_value_size=231, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9765, timestamp=1616393915123, timestamp_type=0, key=None, value={'sequence': 1442, 'machine': 5, 'PID': 3615, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'kworker/3:2', 'ts': 1616393915}, headers=[], checksum=95249066, serialized_key_size=-1, serialized_value_size=234, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9766, timestamp=1616393915123, timestamp_type=0, key=None, value={'sequence': 1443, 'machine': 5, 'PID': 2817, 'TRUN': 0, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'vmtoolsd', 'ts': 1616393915}, headers=[], checksum=411521858, serialized_key_size=-1, serialized_value_size=231, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9767, timestamp=1616393915123, timestamp_type=0, key=None, value={'sequence': 1444, 'machine': 5, 'PID': 2801, 'TRUN': 0, 'TSLPI': 5, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'nautilus', 'ts': 1616393915}, headers=[], checksum=3499728389, serialized_key_size=-1, serialized_value_size=231, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9768, timestamp=1616393915124, timestamp_type=0, key=None, value={'sequence': 1445, 'machine': 5, 'PID': 1496, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'Xorg', 'ts': 1616393915}, headers=[], checksum=184254920, serialized_key_size=-1, serialized_value_size=227, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9769, timestamp=1616393915124, timestamp_type=0, key=None, value={'sequence': 1446, 'machine': 5, 'PID': 2540, 'TRUN': 1, 'TSLPI': 2, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'R', 'CPU': 0.0, 'CMD': 'unity-panel-se', 'ts': 1616393915}, headers=[], checksum=497159381, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9770, timestamp=1616393915124, timestamp_type=0, key=None, value={'sequence': 1447, 'machine': 5, 'PID': 1667, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'haveged', 'ts': 1616393915}, headers=[], checksum=1269594470, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9771, timestamp=1616393915124, timestamp_type=0, key=None, value={'sequence': 1448, 'machine': 5, 'PID': 1542, 'TRUN': 0, 'TSLPI': 17, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'mysqld', 'ts': 1616393915}, headers=[], checksum=2154778612, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9772, timestamp=1616393915124, timestamp_type=0, key=None, value={'sequence': 1449, 'machine': 5, 'PID': 2787, 'TRUN': 0, 'TSLPI': 4, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'goa-daemon', 'ts': 1616393915}, headers=[], checksum=1961916059, serialized_key_size=-1, serialized_value_size=232, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9773, timestamp=1616393915124, timestamp_type=0, key=None, value={'sequence': 1450, 'machine': 5, 'PID': 4253, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'kworker/u256:0', 'ts': 1616393915}, headers=[], checksum=676867097, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9774, timestamp=1616393915124, timestamp_type=0, key=None, value={'sequence': 1451, 'machine': 5, 'PID': 2792, 'TRUN': 0, 'TSLPI': 5, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'evolution-cale', 'ts': 1616393915}, headers=[], checksum=4202237945, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9775, timestamp=1616393915124, timestamp_type=0, key=None, value={'sequence': 1452, 'machine': 5, 'PID': 4147, 'TRUN': 0, 'TSLPI': 4, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'gnome-terminal', 'ts': 1616393915}, headers=[], checksum=217313094, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9776, timestamp=1616393915125, timestamp_type=0, key=None, value={'sequence': 1453, 'machine': 5, 'PID': 2528, 'TRUN': 0, 'TSLPI': 4, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'unity-settings', 'ts': 1616393915}, headers=[], checksum=746569010, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9777, timestamp=1616393915125, timestamp_type=0, key=None, value={'sequence': 1454, 'machine': 5, 'PID': 1189, 'TRUN': 0, 'TSLPI': 4, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'NetworkManager', 'ts': 1616393915}, headers=[], checksum=2497443373, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9778, timestamp=1616393915125, timestamp_type=0, key=None, value={'sequence': 1455, 'machine': 5, 'PID': 2838, 'TRUN': 0, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'mission-contro', 'ts': 1616393915}, headers=[], checksum=2009584201, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9779, timestamp=1616393915125, timestamp_type=0, key=None, value={'sequence': 1456, 'machine': 5, 'PID': 4447, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'apache2', 'ts': 1616393915}, headers=[], checksum=1394254247, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9780, timestamp=1616393915125, timestamp_type=0, key=None, value={'sequence': 1457, 'machine': 5, 'PID': 1399, 'TRUN': 0, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'whoopsie', 'ts': 1616393915}, headers=[], checksum=3093618949, serialized_key_size=-1, serialized_value_size=230, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9781, timestamp=1616393915125, timestamp_type=0, key=None, value={'sequence': 1458, 'machine': 5, 'PID': 1854, 'TRUN': 0, 'TSLPI': 2, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'vmtoolsd', 'ts': 1616393915}, headers=[], checksum=2115049428, serialized_key_size=-1, serialized_value_size=230, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9782, timestamp=1616393915125, timestamp_type=0, key=None, value={'sequence': 1459, 'machine': 5, 'PID': 3123, 'TRUN': 0, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'deja-dup-monit', 'ts': 1616393915}, headers=[], checksum=2950864725, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9783, timestamp=1616393915125, timestamp_type=0, key=None, value={'sequence': 1460, 'machine': 5, 'PID': 4324, 'TRUN': 1, 'TSLPI': 0, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'R', 'CPU': 0.0, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=3511493977, serialized_key_size=-1, serialized_value_size=227, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9784, timestamp=1616393915126, timestamp_type=0, key=None, value={'sequence': 1461, 'machine': 5, 'PID': 1423, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'irqbalance', 'ts': 1616393915}, headers=[], checksum=1679875758, serialized_key_size=-1, serialized_value_size=232, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9785, timestamp=1616393915126, timestamp_type=0, key=None, value={'sequence': 1462, 'machine': 5, 'PID': 4188, 'TRUN': 0, 'TSLPI': 13, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.08, 'CMD': 'drone', 'ts': 1616393915}, headers=[], checksum=849988897, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9786, timestamp=1616393915126, timestamp_type=0, key=None, value={'sequence': 1463, 'machine': 5, 'PID': 4325, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.03, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=3021063144, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9787, timestamp=1616393915126, timestamp_type=0, key=None, value={'sequence': 1464, 'machine': 5, 'PID': 2777, 'TRUN': 0, 'TSLPI': 5, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.03, 'CMD': 'compiz', 'ts': 1616393915}, headers=[], checksum=1293859639, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9788, timestamp=1616393915126, timestamp_type=0, key=None, value={'sequence': 1465, 'machine': 5, 'PID': 4324, 'TRUN': 1, 'TSLPI': 0, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'R', 'CPU': 0.02, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=432020837, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9789, timestamp=1616393915141, timestamp_type=0, key=None, value={'sequence': 1466, 'machine': 5, 'PID': 4327, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=1482042706, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9790, timestamp=1616393915141, timestamp_type=0, key=None, value={'sequence': 1467, 'machine': 5, 'PID': 3615, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'kworker/3:2', 'ts': 1616393915}, headers=[], checksum=1012210144, serialized_key_size=-1, serialized_value_size=234, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9791, timestamp=1616393915141, timestamp_type=0, key=None, value={'sequence': 1468, 'machine': 5, 'PID': 4185, 'TRUN': 0, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'ostinato', 'ts': 1616393915}, headers=[], checksum=3066728350, serialized_key_size=-1, serialized_value_size=231, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9792, timestamp=1616393915141, timestamp_type=0, key=None, value={'sequence': 1469, 'machine': 5, 'PID': 2801, 'TRUN': 0, 'TSLPI': 5, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'nautilus', 'ts': 1616393915}, headers=[], checksum=3978830882, serialized_key_size=-1, serialized_value_size=231, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9793, timestamp=1616393915142, timestamp_type=0, key=None, value={'sequence': 1470, 'machine': 5, 'PID': 2540, 'TRUN': 0, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'unity-panel-se', 'ts': 1616393915}, headers=[], checksum=2266774948, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9794, timestamp=1616393915142, timestamp_type=0, key=None, value={'sequence': 1471, 'machine': 5, 'PID': 2787, 'TRUN': 0, 'TSLPI': 4, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'goa-daemon', 'ts': 1616393915}, headers=[], checksum=3607874012, serialized_key_size=-1, serialized_value_size=232, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9795, timestamp=1616393915144, timestamp_type=0, key=None, value={'sequence': 258, 'machine': 6, 'PID': 52746, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'apache2', 'ts': 1616393915}, headers=[], checksum=1525334172, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9796, timestamp=1616393915144, timestamp_type=0, key=None, value={'sequence': 259, 'machine': 6, 'PID': 52747, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'apache2', 'ts': 1616393915}, headers=[], checksum=1183590283, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9797, timestamp=1616393915144, timestamp_type=0, key=None, value={'sequence': 260, 'machine': 6, 'PID': 52748, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'apache2', 'ts': 1616393915}, headers=[], checksum=1032019528, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9798, timestamp=1616393915144, timestamp_type=0, key=None, value={'sequence': 261, 'machine': 6, 'PID': 52749, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'apache2', 'ts': 1616393915}, headers=[], checksum=2376142791, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9799, timestamp=1616393915144, timestamp_type=0, key=None, value={'sequence': 262, 'machine': 6, 'PID': 52750, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'apache2', 'ts': 1616393915}, headers=[], checksum=1541519250, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9800, timestamp=1616393915144, timestamp_type=0, key=None, value={'sequence': 263, 'machine': 6, 'PID': 51637, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'cupsd', 'ts': 1616393915}, headers=[], checksum=2228425096, serialized_key_size=-1, serialized_value_size=227, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9801, timestamp=1616393915145, timestamp_type=0, key=None, value={'sequence': 264, 'machine': 6, 'PID': 52833, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'sudo', 'ts': 1616393915}, headers=[], checksum=2331324386, serialized_key_size=-1, serialized_value_size=226, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9802, timestamp=1616393915145, timestamp_type=0, key=None, value={'sequence': 265, 'machine': 6, 'PID': 3263, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'sudo', 'ts': 1616393915}, headers=[], checksum=4117435141, serialized_key_size=-1, serialized_value_size=225, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9803, timestamp=1616393915145, timestamp_type=0, key=None, value={'sequence': 266, 'machine': 6, 'PID': 3118, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'sudo', 'ts': 1616393915}, headers=[], checksum=758480078, serialized_key_size=-1, serialized_value_size=225, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9804, timestamp=1616393915145, timestamp_type=0, key=None, value={'sequence': 267, 'machine': 6, 'PID': 51640, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'dbus', 'ts': 1616393915}, headers=[], checksum=1313230217, serialized_key_size=-1, serialized_value_size=226, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9805, timestamp=1616393915145, timestamp_type=0, key=None, value={'sequence': 268, 'machine': 6, 'PID': 52342, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'pickup', 'ts': 1616393915}, headers=[], checksum=2467397281, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9806, timestamp=1616393915145, timestamp_type=0, key=None, value={'sequence': 269, 'machine': 6, 'PID': 2237, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'getty', 'ts': 1616393915}, headers=[], checksum=2989629301, serialized_key_size=-1, serialized_value_size=226, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9807, timestamp=1616393915145, timestamp_type=0, key=None, value={'sequence': 270, 'machine': 6, 'PID': 3100, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'gnome-pty-help', 'ts': 1616393915}, headers=[], checksum=1911690497, serialized_key_size=-1, serialized_value_size=235, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9808, timestamp=1616393915145, timestamp_type=0, key=None, value={'sequence': 271, 'machine': 6, 'PID': 1310, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'getty', 'ts': 1616393915}, headers=[], checksum=1513627649, serialized_key_size=-1, serialized_value_size=226, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9809, timestamp=1616393915145, timestamp_type=0, key=None, value={'sequence': 272, 'machine': 6, 'PID': 1314, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'getty', 'ts': 1616393915}, headers=[], checksum=3917136770, serialized_key_size=-1, serialized_value_size=226, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9810, timestamp=1616393915146, timestamp_type=0, key=None, value={'sequence': 273, 'machine': 6, 'PID': 1321, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'getty', 'ts': 1616393915}, headers=[], checksum=3876703864, serialized_key_size=-1, serialized_value_size=226, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9811, timestamp=1616393915146, timestamp_type=0, key=None, value={'sequence': 274, 'machine': 6, 'PID': 1322, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'getty', 'ts': 1616393915}, headers=[], checksum=3831098592, serialized_key_size=-1, serialized_value_size=226, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9812, timestamp=1616393915146, timestamp_type=0, key=None, value={'sequence': 275, 'machine': 6, 'PID': 1327, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'getty', 'ts': 1616393915}, headers=[], checksum=1054665216, serialized_key_size=-1, serialized_value_size=226, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9813, timestamp=1616393915146, timestamp_type=0, key=None, value={'sequence': 276, 'machine': 6, 'PID': 2983, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'cat', 'ts': 1616393915}, headers=[], checksum=2069997717, serialized_key_size=-1, serialized_value_size=224, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9814, timestamp=1616393915146, timestamp_type=0, key=None, value={'sequence': 277, 'machine': 6, 'PID': 2411, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'dbus-launch', 'ts': 1616393915}, headers=[], checksum=239238316, serialized_key_size=-1, serialized_value_size=232, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9815, timestamp=1616393915146, timestamp_type=0, key=None, value={'sequence': 278, 'machine': 6, 'PID': 2414, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'dbus-daemon', 'ts': 1616393915}, headers=[], checksum=3520550809, serialized_key_size=-1, serialized_value_size=232, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9816, timestamp=1616393915146, timestamp_type=0, key=None, value={'sequence': 279, 'machine': 6, 'PID': 1392, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'atd', 'ts': 1616393915}, headers=[], checksum=2311056625, serialized_key_size=-1, serialized_value_size=224, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9817, timestamp=1616393915146, timestamp_type=0, key=None, value={'sequence': 280, 'machine': 6, 'PID': 1769, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'kauditd', 'ts': 1616393915}, headers=[], checksum=2595863293, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9818, timestamp=1616393915147, timestamp_type=0, key=None, value={'sequence': 281, 'machine': 6, 'PID': 3175, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 2, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'ext4-rsv-conve', 'ts': 1616393915}, headers=[], checksum=2245785629, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9819, timestamp=1616393915147, timestamp_type=0, key=None, value={'sequence': 282, 'machine': 6, 'PID': 52796, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': 'N', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'kworker/u256:1', 'ts': 1616393915}, headers=[], checksum=1002806140, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9820, timestamp=1616393915147, timestamp_type=0, key=None, value={'sequence': 283, 'machine': 6, 'PID': 3147, 'TRUN': 1, 'TSLPI': 12, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 1.0, 'CMD': 'drone', 'ts': 1616393915}, headers=[], checksum=2682828383, serialized_key_size=-1, serialized_value_size=227, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9821, timestamp=1616393915148, timestamp_type=0, key=None, value={'sequence': 284, 'machine': 6, 'PID': 1494, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'Xorg', 'ts': 1616393915}, headers=[], checksum=321146773, serialized_key_size=-1, serialized_value_size=226, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9822, timestamp=1616393915148, timestamp_type=0, key=None, value={'sequence': 285, 'machine': 6, 'PID': 3144, 'TRUN': 0, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'ostinato', 'ts': 1616393915}, headers=[], checksum=2579918872, serialized_key_size=-1, serialized_value_size=230, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9823, timestamp=1616393915148, timestamp_type=0, key=None, value={'sequence': 286, 'machine': 6, 'PID': 3282, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=2221735152, serialized_key_size=-1, serialized_value_size=227, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9824, timestamp=1616393915149, timestamp_type=0, key=None, value={'sequence': 287, 'machine': 6, 'PID': 2766, 'TRUN': 0, 'TSLPI': 8, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'compiz', 'ts': 1616393915}, headers=[], checksum=4182269344, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9825, timestamp=1616393915149, timestamp_type=0, key=None, value={'sequence': 288, 'machine': 6, 'PID': 52888, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=405483535, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9826, timestamp=1616393915149, timestamp_type=0, key=None, value={'sequence': 289, 'machine': 6, 'PID': 52885, 'TRUN': 1, 'TSLPI': 0, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'R', 'CPU': 0.01, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=2598302694, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9827, timestamp=1616393915241, timestamp_type=0, key=None, value={'sequence': 1426, 'machine': 7, 'PID': 1401, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'irqbalance', 'ts': 1616393915}, headers=[], checksum=661392567, serialized_key_size=-1, serialized_value_size=232, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9828, timestamp=1616393915241, timestamp_type=0, key=None, value={'sequence': 1427, 'machine': 7, 'PID': 2576, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'upstart-dbus-b', 'ts': 1616393915}, headers=[], checksum=714250440, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9829, timestamp=1616393915241, timestamp_type=0, key=None, value={'sequence': 1428, 'machine': 7, 'PID': 3339, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'kworker/u256:1', 'ts': 1616393915}, headers=[], checksum=2437862361, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9830, timestamp=1616393915241, timestamp_type=0, key=None, value={'sequence': 1429, 'machine': 7, 'PID': 2608, 'TRUN': 0, 'TSLPI': 4, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'hud-service', 'ts': 1616393915}, headers=[], checksum=1312566159, serialized_key_size=-1, serialized_value_size=233, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9831, timestamp=1616393915241, timestamp_type=0, key=None, value={'sequence': 1430, 'machine': 7, 'PID': 2093, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'apache2', 'ts': 1616393915}, headers=[], checksum=286651106, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9832, timestamp=1616393915241, timestamp_type=0, key=None, value={'sequence': 1431, 'machine': 7, 'PID': 3401, 'TRUN': 0, 'TSLPI': 0, 'TSLPU': 0, 'POLI': '0', 'NICE': 0, 'PRI': 0, 'RTPR': 0, 'CPUNR': 0, 'Status': '-', 'EXC': 15, 'State': 'E', 'CPU': 0.0, 'CMD': '<dhclient>', 'ts': 1616393915}, headers=[], checksum=2212644906, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9833, timestamp=1616393915242, timestamp_type=0, key=None, value={'sequence': 1432, 'machine': 7, 'PID': 3128, 'TRUN': 1, 'TSLPI': 11, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 1.09, 'CMD': 'drone', 'ts': 1616393915}, headers=[], checksum=536064411, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9834, timestamp=1616393915242, timestamp_type=0, key=None, value={'sequence': 1433, 'machine': 7, 'PID': 1457, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.07, 'CMD': 'Xorg', 'ts': 1616393915}, headers=[], checksum=1331019555, serialized_key_size=-1, serialized_value_size=227, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9835, timestamp=1616393915242, timestamp_type=0, key=None, value={'sequence': 1434, 'machine': 7, 'PID': 3103, 'TRUN': 0, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.04, 'CMD': 'ostinato', 'ts': 1616393915}, headers=[], checksum=1329075524, serialized_key_size=-1, serialized_value_size=231, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9836, timestamp=1616393915243, timestamp_type=0, key=None, value={'sequence': 1435, 'machine': 7, 'PID': 2821, 'TRUN': 0, 'TSLPI': 4, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.02, 'CMD': 'compiz', 'ts': 1616393915}, headers=[], checksum=2889693107, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9837, timestamp=1616393915244, timestamp_type=0, key=None, value={'sequence': 1436, 'machine': 7, 'PID': 3293, 'TRUN': 1, 'TSLPI': 0, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'R', 'CPU': 0.02, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=1154627118, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9838, timestamp=1616393915244, timestamp_type=0, key=None, value={'sequence': 1437, 'machine': 7, 'PID': 3294, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.02, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=3706390522, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9839, timestamp=1616393915328, timestamp_type=0, key=None, value={'sequence': 1471, 'machine': 8, 'PID': 3103, 'TRUN': 0, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.02, 'CMD': 'ostinato', 'ts': 1616393915}, headers=[], checksum=978115600, serialized_key_size=-1, serialized_value_size=231, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9840, timestamp=1616393915330, timestamp_type=0, key=None, value={'sequence': 1472, 'machine': 8, 'PID': 3292, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.02, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=1616061069, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ...
# ConsumerRecord(topic='process', partition=0, offset=9845, timestamp=1616393915340, timestamp_type=0, key=None, value={'sequence': 1477, 'machine': 8, 'PID': 2849, 'TRUN': 0, 'TSLPI': 5, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'nautilus', 'ts': 1616393915}, headers=[], checksum=4093929939, serialized_key_size=-1, serialized_value_size=230, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9846, timestamp=1616393915340, timestamp_type=0, key=None, value={'sequence': 1478, 'machine': 8, 'PID': 1967, 'TRUN': 0, 'TSLPI': 2, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'vmtoolsd', 'ts': 1616393915}, headers=[], checksum=3125034048, serialized_key_size=-1, serialized_value_size=230, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9847, timestamp=1616393915342, timestamp_type=0, key=None, value={'sequence': 1479, 'machine': 8, 'PID': 2551, 'TRUN': 0, 'TSLPI': 4, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'bamfdaemon', 'ts': 1616393915}, headers=[], checksum=3158811221, serialized_key_size=-1, serialized_value_size=232, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9848, timestamp=1616393915342, timestamp_type=0, key=None, value={'sequence': 1480, 'machine': 8, 'PID': 1401, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'irqbalance', 'ts': 1616393915}, headers=[], checksum=2077996670, serialized_key_size=-1, serialized_value_size=232, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9849, timestamp=1616393915342, timestamp_type=0, key=None, value={'sequence': 1481, 'machine': 8, 'PID': 6497, 'TRUN': 2, 'TSLPI': 54, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'R', 'CPU': 0.19, 'CMD': 'firefox', 'ts': 1616393915}, headers=[], checksum=3370031399, serialized_key_size=-1, serialized_value_size=231, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9850, timestamp=1616393915355, timestamp_type=0, key=None, value={'sequence': 1482, 'machine': 8, 'PID': 6555, 'TRUN': 1, 'TSLPI': 21, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'R', 'CPU': 0.12, 'CMD': 'Web-Content Content', 'ts': 1616393915}, headers=[], checksum=954461761, serialized_key_size=-1, serialized_value_size=243, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9851, timestamp=1616393915355, timestamp_type=0, key=None, value={'sequence': 1483, 'machine': 8, 'PID': 1457, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.09, 'CMD': 'Xorg', 'ts': 1616393915}, headers=[], checksum=119540645, serialized_key_size=-1, serialized_value_size=227, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9852, timestamp=1616393915356, timestamp_type=0, key=None, value={'sequence': 1484, 'machine': 8, 'PID': 2821, 'TRUN': 1, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'R', 'CPU': 0.04, 'CMD': 'compiz', 'ts': 1616393915}, headers=[], checksum=1318250523, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9853, timestamp=1616393915356, timestamp_type=0, key=None, value={'sequence': 1485, 'machine': 8, 'PID': 2596, 'TRUN': 0, 'TSLPI': 4, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.02, 'CMD': 'ibus-ui-gtk3', 'ts': 1616393915}, headers=[], checksum=2190590463, serialized_key_size=-1, serialized_value_size=235, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9854, timestamp=1616393915357, timestamp_type=0, key=None, value={'sequence': 1486, 'machine': 8, 'PID': 3103, 'TRUN': 0, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'ostinato', 'ts': 1616393915}, headers=[], checksum=1465959269, serialized_key_size=-1, serialized_value_size=231, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9855, timestamp=1616393915357, timestamp_type=0, key=None, value={'sequence': 1487, 'machine': 8, 'PID': 6452, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=424643663, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9856, timestamp=1616393915357, timestamp_type=0, key=None, value={'sequence': 1488, 'machine': 8, 'PID': 6449, 'TRUN': 1, 'TSLPI': 0, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'R', 'CPU': 0.01, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=1459394979, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9857, timestamp=1616393915357, timestamp_type=0, key=None, value={'sequence': 1489, 'machine': 8, 'PID': 6451, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=373802430, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9858, timestamp=1616393915358, timestamp_type=0, key=None, value={'sequence': 1490, 'machine': 8, 'PID': 3292, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=1244239122, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9859, timestamp=1616393915358, timestamp_type=0, key=None, value={'sequence': 1491, 'machine': 8, 'PID': 6450, 'TRUN': 1, 'TSLPI': 0, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 20, 'PRI': 100, 'RTPR': 0, 'CPUNR': 0, 'Status': '0', 'EXC': 0, 'State': 'R', 'CPU': 0.01, 'CMD': 'atop', 'ts': 1616393915}, headers=[], checksum=1569568573, serialized_key_size=-1, serialized_value_size=228, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9860, timestamp=1616393915358, timestamp_type=0, key=None, value={'sequence': 1492, 'machine': 8, 'PID': 2782, 'TRUN': 0, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.01, 'CMD': 'ibus-engine-si', 'ts': 1616393915}, headers=[], checksum=3718909947, serialized_key_size=-1, serialized_value_size=237, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9861, timestamp=1616393915359, timestamp_type=0, key=None, value={'sequence': 1493, 'machine': 8, 'PID': 2608, 'TRUN': 0, 'TSLPI': 4, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'hud-service', 'ts': 1616393915}, headers=[], checksum=4069419715, serialized_key_size=-1, serialized_value_size=233, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9862, timestamp=1616393915359, timestamp_type=0, key=None, value={'sequence': 1494, 'machine': 8, 'PID': 2849, 'TRUN': 0, 'TSLPI': 5, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'nautilus', 'ts': 1616393915}, headers=[], checksum=1772469729, serialized_key_size=-1, serialized_value_size=230, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9863, timestamp=1616393915364, timestamp_type=0, key=None, value={'sequence': 1495, 'machine': 8, 'PID': 2633, 'TRUN': 0, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'unity-panel-se', 'ts': 1616393915}, headers=[], checksum=2543476000, serialized_key_size=-1, serialized_value_size=236, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9864, timestamp=1616393915365, timestamp_type=0, key=None, value={'sequence': 1496, 'machine': 8, 'PID': 1967, 'TRUN': 0, 'TSLPI': 2, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'vmtoolsd', 'ts': 1616393915}, headers=[], checksum=736439654, serialized_key_size=-1, serialized_value_size=230, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9865, timestamp=1616393915368, timestamp_type=0, key=None, value={'sequence': 1497, 'machine': 8, 'PID': 3504, 'TRUN': 0, 'TSLPI': 1, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'kworker/1:0', 'ts': 1616393915}, headers=[], checksum=916068006, serialized_key_size=-1, serialized_value_size=233, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9866, timestamp=1616393915376, timestamp_type=0, key=None, value={'sequence': 1498, 'machine': 8, 'PID': 2882, 'TRUN': 0, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.0, 'CMD': 'vmtoolsd', 'ts': 1616393915}, headers=[], checksum=1953128177, serialized_key_size=-1, serialized_value_size=230, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9867, timestamp=1616393915377, timestamp_type=0, key=None, value={'sequence': 1499, 'machine': 8, 'PID': 6497, 'TRUN': 0, 'TSLPI': 56, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.18, 'CMD': 'firefox', 'ts': 1616393915}, headers=[], checksum=3973807990, serialized_key_size=-1, serialized_value_size=231, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9868, timestamp=1616393915377, timestamp_type=0, key=None, value={'sequence': 1500, 'machine': 8, 'PID': 6555, 'TRUN': 0, 'TSLPI': 22, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 3, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.13, 'CMD': 'Web-Content Content', 'ts': 1616393915}, headers=[], checksum=1442629589, serialized_key_size=-1, serialized_value_size=243, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9869, timestamp=1616393915377, timestamp_type=0, key=None, value={'sequence': 1501, 'machine': 8, 'PID': 2821, 'TRUN': 0, 'TSLPI': 4, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 1, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.04, 'CMD': 'compiz', 'ts': 1616393915}, headers=[], checksum=512972128, serialized_key_size=-1, serialized_value_size=229, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9870, timestamp=1616393915377, timestamp_type=0, key=None, value={'sequence': 1502, 'machine': 8, 'PID': 2559, 'TRUN': 0, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.02, 'CMD': 'ibus-daemon', 'ts': 1616393915}, headers=[], checksum=3497094548, serialized_key_size=-1, serialized_value_size=234, serialized_header_size=-1)
# ConsumerRecord(topic='process', partition=0, offset=9871, timestamp=1616393915377, timestamp_type=0, key=None, value={'sequence': 1503, 'machine': 8, 'PID': 3103, 'TRUN': 0, 'TSLPI': 3, 'TSLPU': 0, 'POLI': 'norm', 'NICE': 0, 'PRI': 120, 'RTPR': 0, 'CPUNR': 2, 'Status': '0', 'EXC': 0, 'State': 'S', 'CPU': 0.02, 'CMD': 'ostinato', 'ts': 1616393915}, headers=[], checksum=2048849533, serialized_key_size=-1, serialized_value_size=231, serialized_header_size=-1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-388cac2e5229> in <module>
#      40
#      41     consumer = connect_kafka_consumer()
# ---> 42     consume_messages(consumer,fig,ax)
#      43
#
# <ipython-input-3-388cac2e5229> in consume_messages(consumer, fig, ax)
#      31     try:
#      32         # print('Waiting for messages')
# ---> 33         for message in consumer:
#      34             print(message)
#      35     except Exception as ex:
#
# ~/.local/lib/python3.8/site-packages/kafka/consumer/group.py in __next__(self)
#    1190             return self.next_v1()
#    1191         else:
# -> 1192             return self.next_v2()
#    1193
#    1194     def next_v2(self):
#
# ~/.local/lib/python3.8/site-packages/kafka/consumer/group.py in next_v2(self)
#    1198                 self._iterator = self._message_generator_v2()
#    1199             try:
# -> 1200                 return next(self._iterator)
#    1201             except StopIteration:
#    1202                 self._iterator = None
#
# ~/.local/lib/python3.8/site-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1113     def _message_generator_v2(self):
#    1114         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1115         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1116         for tp, records in six.iteritems(record_map):
#    1117             # Generators are stateful, and it is possible that the tp / records
#
# ~/.local/lib/python3.8/site-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     652         remaining = timeout_ms
#     653         while True:
# --> 654             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     655             if records:
#     656                 return records
#
# ~/.local/lib/python3.8/site-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     699
#     700         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 701         self._client.poll(timeout_ms=timeout_ms)
#     702         # after the long poll, we should check whether the group needs to rebalance
#     703         # prior to returning data so that the group can stabilize faster
#
# ~/.local/lib/python3.8/site-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     598                     timeout = max(0, timeout)  # avoid negative timeouts
#     599
# --> 600                 self._poll(timeout / 1000)
#     601
#     602             # called without the lock to avoid deadlock potential
#
# ~/.local/lib/python3.8/site-packages/kafka/client_async.py in _poll(self, timeout)
#     630
#     631         start_select = time.time()
# --> 632         ready = self._selector.select(timeout)
#     633         end_select = time.time()
#     634         if self._sensors:
#
# /usr/lib/python3.8/selectors.py in select(self, timeout)
#     466             ready = []
#     467             try:
# --> 468                 fd_event_list = self._selector.poll(timeout, max_ev)
#     469             except InterruptedError:
#     470                 return ready
#
# KeyboardInterrupt:
